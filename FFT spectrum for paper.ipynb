# %% [markdown]
# #A notebook to generate an additional figure for the paper
# ##figure shows FFT output (i.e. K_p) for no light, LO-only, and LO+signal.
# ## TODO:
# - take the no-light data

# %%
import numpy as np

# %%
# %pylab inline
# Out:
# Welcome to pylab, a matplotlib-based Python environment [backend: module://IPython.zmq.pylab.backend_inline].
# For more information, type 'help(pylab)'.

# %%
vacuum_npz = np.load("/home/photon/data/07-03-2014/13-37-57_raw.npz")
data_npz = np.load("/home/photon/data/07-03-2014/13-49-56_raw.npz")
data = data_npz['dataOut']
vacuum = vacuum_npz['dataOut']
ncount = data_npz['ncount']
Kp_vac = np.average(vacuum,axis=(1,2))
scaled_vc = np.sqrt(2.0/ncount)*(data - Kp_vac.reshape(600,1,1))

# %%
plot(log10(abs(np.average(vacuum[0:300],axis=(1,2)))))
plot(log10(abs(np.average(data[0:300],axis=(1,2)))))

# %%
plot(log10(abs(np.average(vacuum[150:250],axis=(1,2)))))
plot(log10(abs(np.average(data[150:250],axis=(1,2)))))

# %%
plot(log10(abs(np.average(scaled_vc[0:300],axis=(1,2)))))
